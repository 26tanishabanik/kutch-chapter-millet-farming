# %% [markdown]
# # OMDENA Millets project - EDA and Feature Engineering

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("data_omdena_without_imputation.csv", delimiter= ";", index_col=0)
df.head()
# Out:
#                                      Types of Millets Common Name Category  \
# ID
# 1                   Pearl millet (Pennisetum glaucum)       PEARL    Major
# 2                   Finger millet (Eleusine coracana)      FINGER    Major
# 3                    Foxtail millet (Setaria italica)     FOXTAIL    Minor
# 4   Proso millet (Panicum miliaceum) (Chena in India)       PROSO    Major
# 5                  Little millet (Panicum sumatrense)      LITTLE    Minor
#
#     Drought resistant  Flood Resistant  Min Temperature (ºC)  \
# ID
# 1                   1                0                    30
# 2                   1                0                    26
# 3                   1                0                     5
# 4                   1                0                    20
# 5                   0                1                    25
#
#     Max Temperature (ºC)  pH level of the soil Min  pH level of the soil Max  \
# ID
# 1                     34                       6.0                       7.0
# 2                     29                       4.5                       7.5
# 3                     35                       5.5                       7.0
# 4                     30                       5.5                       6.5
# 5                     30                       5.5                       6.5
#
#    Soil type  ...  Ash (g)  Crude Fibre (g)  Carbo- hydrates (g)  \
# ID            ...
# 1     LC, SL  ...     1.37            11.49                61.78
# 2          L  ...     2.04            11.18                66.82
# 3         SL  ...     0.00             8.00                60.90
# 4      SL, A  ...     1.72             6.39                66.19
# 5      C,L,S  ...     1.34             7.72                65.55
#
#     Energy (kcal)  Calcium (mg)  Iron (mg)  Thiamine (mg)  Ribo- flavin (mg)  \
# ID
# 1           348.0         27.35       6.42           0.25               0.20
# 2           320.7        364.00       4.62           0.37               0.17
# 3           331.0         31.00       2.80           0.59               0.11
# 4           331.7         15.27       2.34           0.29               0.20
# 5           346.3         16.06       1.26           0.26               0.05
#
#    Nia- cin (mg) Price (US$ / Kg)
# ID
# 1           0.86             19.0
# 2           1.30             19.0
# 3           3.20             24.0
# 4           1.49              NaN
# 5           1.29             20.0
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Exploratory Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 1 to 34
# Data columns (total 43 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Types of Millets                     34 non-null     object
#  1   Common Name                          34 non-null     object
#  2   Category                             34 non-null     object
#  3   Drought resistant                    34 non-null     int64
#  4   Flood Resistant                      34 non-null     int64
#  5   Min Temperature (ºC)                 34 non-null     int64
#  6   Max Temperature (ºC)                 34 non-null     int64
#  7   pH level of the soil Min             34 non-null     float64
#  8   pH level of the soil Max             34 non-null     float64
#  9   Soil type                            34 non-null     object
#  10  Soil Salinity (dS/m) Min             34 non-null     float64
#  11  Soil Salinity (dS/m) Max             34 non-null     float64
#  12  Rainfall Required (cm) Min           34 non-null     int64
#  13  Rainfall Required (cm) Max           34 non-null     int64
#  14  Altitude range (m) Min               34 non-null     int64
#  15  Altitude range (m) Max               34 non-null     int64
#  16  Soil Temperature (ºC) Min            28 non-null     float64
#  17  Soil Temperature (ºC) Max            28 non-null     float64
#  18  Soil moisture
# min                    34 non-null     object
#  19  Soil moisture
# max                    34 non-null     object
#  20  Light Duration (hours) Min           21 non-null     float64
#  21  Light Duration (hours) Max           22 non-null     float64
#  22  Land usage for each crop (t/ha) Min  34 non-null     float64
#  23  Land usage for each crop (t/ha) Max  34 non-null     float64
#  24  Seeding Rate (kg/ha) Min             22 non-null     float64
#  25  Seeding Rate (kg/ha) Max             23 non-null     float64
#  26  Maturity time (days) Min             33 non-null     float64
#  27  Maturity time (days) Max             33 non-null     float64
#  28  Planting Depth (cm) Min              28 non-null     float64
#  29  Planting Depth (cm) Max              28 non-null     float64
#  30  Planting Geometry (cm x cm)          34 non-null     object
#  31  Protein (g)                          17 non-null     float64
#  32  Fat (g)                              17 non-null     float64
#  33  Ash (g)                              17 non-null     float64
#  34  Crude Fibre (g)                      17 non-null     float64
#  35  Carbo- hydrates (g)                  17 non-null     float64
#  36  Energy (kcal)                        17 non-null     float64
#  37  Calcium (mg)                         17 non-null     float64
#  38  Iron (mg)                            17 non-null     float64
#  39  Thiamine (mg)                        17 non-null     float64
#  40  Ribo- flavin (mg)                    17 non-null     float64
#  41  Nia- cin (mg)                        17 non-null     float64
#  42  Price (US$ / Kg)                     13 non-null     float64
# dtypes: float64(28), int64(8), object(7)
# memory usage: 11.7+ KB

# %%
#Missing values
df.isna().sum()
# Out:
# Types of Millets                        0
# Common Name                             0
# Category                                0
# Drought resistant                       0
# Flood Resistant                         0
# Min Temperature (ºC)                    0
# Max Temperature (ºC)                    0
# pH level of the soil Min                0
# pH level of the soil Max                0
# Soil type                               0
# Soil Salinity (dS/m) Min                0
# Soil Salinity (dS/m) Max                0
# Rainfall Required (cm) Min              0
# Rainfall Required (cm) Max              0
# Altitude range (m) Min                  0
# Altitude range (m) Max                  0
# Soil Temperature (ºC) Min               6
# Soil Temperature (ºC) Max               6
# Soil moisture\nmin                      0
# Soil moisture\nmax                      0
# Light Duration (hours) Min             13
# Light Duration (hours) Max             12
# Land usage for each crop (t/ha) Min     0
# Land usage for each crop (t/ha) Max     0
# Seeding Rate (kg/ha) Min               12
# Seeding Rate (kg/ha) Max               11
# Maturity time (days) Min                1
# Maturity time (days) Max                1
# Planting Depth (cm) Min                 6
# Planting Depth (cm) Max                 6
# Planting Geometry (cm x cm)             0
# Protein (g)                            17
# Fat (g)                                17
# Ash (g)                                17
# Crude Fibre (g)                        17
# Carbo- hydrates (g)                    17
# Energy (kcal)                          17
# Calcium (mg)                           17
# Iron (mg)                              17
# Thiamine (mg)                          17
# Ribo- flavin (mg)                      17
# Nia- cin (mg)                          17
# Price (US$ / Kg)                       21
# dtype: int64

# %% [markdown]
# ### Imputation - Simple imputer

# %%
#Identify columns with non-numeric data
non_numeric_cols = df.select_dtypes(exclude=[int, float]).columns

# %%
#Select only numeric columns for imputation
numeric_cols = df.columns.difference(non_numeric_cols)

# %%
#Perform mean imputation on numeric columns
imputer = SimpleImputer(strategy='mean')
df_imputed = df.copy()
df_imputed[numeric_cols] = imputer.fit_transform(df[numeric_cols])

# %%
#Check the imputed DataFrame
df_imputed.head()
# Out:
#                                      Types of Millets Common Name Category  \
# ID
# 1                   Pearl millet (Pennisetum glaucum)       PEARL    Major
# 2                   Finger millet (Eleusine coracana)      FINGER    Major
# 3                    Foxtail millet (Setaria italica)     FOXTAIL    Minor
# 4   Proso millet (Panicum miliaceum) (Chena in India)       PROSO    Major
# 5                  Little millet (Panicum sumatrense)      LITTLE    Minor
#
#     Drought resistant  Flood Resistant  Min Temperature (ºC)  \
# ID
# 1                 1.0              0.0                  30.0
# 2                 1.0              0.0                  26.0
# 3                 1.0              0.0                   5.0
# 4                 1.0              0.0                  20.0
# 5                 0.0              1.0                  25.0
#
#     Max Temperature (ºC)  pH level of the soil Min  pH level of the soil Max  \
# ID
# 1                   34.0                       6.0                       7.0
# 2                   29.0                       4.5                       7.5
# 3                   35.0                       5.5                       7.0
# 4                   30.0                       5.5                       6.5
# 5                   30.0                       5.5                       6.5
#
#    Soil type  ...  Ash (g)  Crude Fibre (g)  Carbo- hydrates (g)  \
# ID            ...
# 1     LC, SL  ...     1.37            11.49                61.78
# 2          L  ...     2.04            11.18                66.82
# 3         SL  ...     0.00             8.00                60.90
# 4      SL, A  ...     1.72             6.39                66.19
# 5      C,L,S  ...     1.34             7.72                65.55
#
#     Energy (kcal)  Calcium (mg)  Iron (mg)  Thiamine (mg)  Ribo- flavin (mg)  \
# ID
# 1           348.0         27.35       6.42           0.25               0.20
# 2           320.7        364.00       4.62           0.37               0.17
# 3           331.0         31.00       2.80           0.59               0.11
# 4           331.7         15.27       2.34           0.29               0.20
# 5           346.3         16.06       1.26           0.26               0.05
#
#    Nia- cin (mg) Price (US$ / Kg)
# ID
# 1           0.86        19.000000
# 2           1.30        19.000000
# 3           3.20        24.000000
# 4           1.49        17.244878
# 5           1.29        20.000000
#
# [5 rows x 43 columns]

# %%
#Check the count of missing values after imputation
df_imputed.isna().any().any()
# Out:
# False

# %%
df_imputed.head()
# Out:
#                                      Types of Millets Common Name Category  \
# ID
# 1                   Pearl millet (Pennisetum glaucum)       PEARL    Major
# 2                   Finger millet (Eleusine coracana)      FINGER    Major
# 3                    Foxtail millet (Setaria italica)     FOXTAIL    Minor
# 4   Proso millet (Panicum miliaceum) (Chena in India)       PROSO    Major
# 5                  Little millet (Panicum sumatrense)      LITTLE    Minor
#
#     Drought resistant  Flood Resistant  Min Temperature (ºC)  \
# ID
# 1                 1.0              0.0                  30.0
# 2                 1.0              0.0                  26.0
# 3                 1.0              0.0                   5.0
# 4                 1.0              0.0                  20.0
# 5                 0.0              1.0                  25.0
#
#     Max Temperature (ºC)  pH level of the soil Min  pH level of the soil Max  \
# ID
# 1                   34.0                       6.0                       7.0
# 2                   29.0                       4.5                       7.5
# 3                   35.0                       5.5                       7.0
# 4                   30.0                       5.5                       6.5
# 5                   30.0                       5.5                       6.5
#
#    Soil type  ...  Ash (g)  Crude Fibre (g)  Carbo- hydrates (g)  \
# ID            ...
# 1     LC, SL  ...     1.37            11.49                61.78
# 2          L  ...     2.04            11.18                66.82
# 3         SL  ...     0.00             8.00                60.90
# 4      SL, A  ...     1.72             6.39                66.19
# 5      C,L,S  ...     1.34             7.72                65.55
#
#     Energy (kcal)  Calcium (mg)  Iron (mg)  Thiamine (mg)  Ribo- flavin (mg)  \
# ID
# 1           348.0         27.35       6.42           0.25               0.20
# 2           320.7        364.00       4.62           0.37               0.17
# 3           331.0         31.00       2.80           0.59               0.11
# 4           331.7         15.27       2.34           0.29               0.20
# 5           346.3         16.06       1.26           0.26               0.05
#
#    Nia- cin (mg) Price (US$ / Kg)
# ID
# 1           0.86        19.000000
# 2           1.30        19.000000
# 3           3.20        24.000000
# 4           1.49        17.244878
# 5           1.29        20.000000
#
# [5 rows x 43 columns]

# %%
#df_imputed to a CSV file
df_imputed.to_csv("data_omdena_imputed.csv", sep=";", index=True)
